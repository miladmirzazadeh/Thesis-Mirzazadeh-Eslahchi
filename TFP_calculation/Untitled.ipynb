# %%
# Out:
# Error importing in API mode: ImportError("dlopen(/Users/milad/opt/anaconda3/lib/python3.8/site-packages/_rinterface_cffi_api.abi3.so, 0x0002): symbol not found in flat namespace '_R_BaseEnv'")
# Trying to import in ABI mode.
# Connection Test: Pi from R is 3.141592653589793
# Success: 'prodest' library is ready to use!

# %%
def calculate_w():
    pass
    


def calculate_rent():
    pass

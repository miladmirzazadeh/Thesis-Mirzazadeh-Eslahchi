# %%
import pandas as pd 
it_tenders_2019= pd.read_csv("Opentender/data-it-csv/data-it-2019.csv", sep=';')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 it_tenders_2019= pd.read_csv("Opentender/data-it-csv/data-it-2019.csv", sep=';')
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
bid_price_available = it_tenders_2019[it_tenders_2019["bid_price_EUR"].notna()]
lot_estimated_price_available = it_tenders_2019[it_tenders_2019["lot_estimatedPrice_EUR"].notna()]
winning = it_tenders_2019[it_tenders_2019["bid_isWinning"]=="yes"]

# %%
import numpy as np 
winning_with_bids = it_tenders_2019[np.logical_and(it_tenders_2019.bid_price_EUR.notna(), it_tenders_2019.bid_isWinning == "yes")]

# %%
winning_with_estimated_price = it_tenders_2019[np.logical_and(it_tenders_2019.lot_estimatedPrice_EUR.notna(), it_tenders_2019.bid_isWinning == "yes")]

# %%
rows_with_both_bid_and_estimated = it_tenders_2019[np.logical_and(it_tenders_2019.lot_estimatedPrice_EUR.notna(), it_tenders_2019.bid_price_EUR.notna())]

# %%
rent = rows_with_both_bid_and_estimated.lot_estimatedPrice_EUR - rows_with_both_bid_and_estimated.bid_price_EUR

# %%
print("mean of rents: ", np.mean(rent))
print("sigma of rents: " , np.std(rent))
# Out:
# mean of rents:  21128.5576994996
# sigma of rents:  7919828.135395073

# %%
print(len(bid_price_available))
print(len(winning))
# Out:
# 588925
# 617054

# %%
len(winning_with_bids)
# Out:
# 588925

# %%
len(winning_with_estimated_price)
# Out:
# 581838
